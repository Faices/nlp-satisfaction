# %%
import sys
import os
sys.path.append(os.path.abspath('../')) ## needed to import the function.py file
from functions import *
# Out:
# 2023-03-15 10:27:31.535917: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
## Import dataframe
filelocation = '../../data/DataText'
data = pd.read_feather(filelocation)
data = data
data = data[data.yearmonth == "2020-06-01"]
docs = data["Kommentar"].values

# %%
#Select Topic model
topic_model = BERTopic.load("../../models/BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_Trends_June_2020.model")
model = topic_model

## Further reduce topics
#topic_model.reduce_topics(docs, nr_topics=16)

# %%
model.get_topic_info()
# Out:
#     Topic  Count                                               Name
# 0      -1     13                -1_angemessener_umfeld_traf_produkt
# 1       0    137                 0_anschluss_zug_verbindung_direkte
# 2       1     77                          1_app_ticket_lösen_kaufen
# 3       2     61              2_tickets_spartickets_tageskarte_velo
# 4       3     63    3_maskenpflicht_einführen_pflicht_obligatorisch
# 5       4     53                        4_wc_toiletten_wcs_toilette
# 6       5     58                  5_züge_stosszeiten_zügen_vorallem
# 7       6     39    6_sparbillette_sparbillete_sparbilette_anbieten
# 8       7     35                   7_sitze_sauberkeit_reinigen_laut
# 9       8     46                   8_tragen_masken_maske_passagiere
# 10      9     38                        9_preise_preis_senken_klass
# 11     10     32  10_sicherheitspersonal_sicherheitsleute_sicher...
# 12     11     29                11_zufrieden_gepasst_happy_geklappt
# 13     12     25                          12_teuer_zonen_preis_geld
# 14     13     34               13_postauto_bahnfahrt_fahrt_busfahrt
# 15     14     38                 14_knapp_minuten_warten_verbindung
# 16     15     19                  15_fahrrad_stromer_fahrräder_bike
# 17     16     23                      16_teuer_00_schüler_studenten
# 18     17     22         17_speisewagen_bedient_gefehlt_gastronomie
# 19     18     19            18_klimaanlage_kalt_klima_funktionierte
# 20     19     29                19_corona_trug_abstandsregeln_maske
# 21     20     20            20_zugpersonal_ruhe_genügend_freundlich
# 22     21     21               21_maskenpflicht_öv_zügen_zugwaggons
# 23     22     17          22_maske_eingehalten_maskenpflicht_tragen
# 24     23     21             23_bistro_informiert_verspätete_abfuhr
# 25     24     21                     24_wagen_laut_menschen_störend
# 26     25     29                    25_corona_gefahren_zug_angenehm
# 27     26     16                   26_laden_handy_termin_smartphone
# 28     27     18          27_siehe_vorherigen_kommentar_geschrieben
# 29     28     18              28_bushaltestelle_fuhr_fährt_lugnorre
# 30     29     13              29_türen_öffnen_automatische_berühren
# 31     30     15                        30_rhb_fahrplan_linie_busse
# 32     31     26                   31_gerne_zufrieden_angebot_fahre
# 33     32     15                 32_wlan_wifi_freesurf_rollmaterial
# 34     33     15                 33_häufig_raucher_rauchfrei_werfen
# 35     34     19            34_bessere_verfügung_veloplätze_stellen
# 36     35     17               35_spät_verspätung_abfahrt_verspätet
# 37     36     12               36_ic_bleibt_littering_bahnanschluss
# 38     37     24            37_klasse_wagen_wünschen_klassenwechsel
# 39     38     16                 38_bike_plattform_lift_kinderwagen
# 40     39     15                   39_verspätungen_takt_bisschen_ga
# 41     40     13                40_perrons_mühsam_einsteigen_plätze
# 42     41      9                41_machbar_schweinen_kfz_berspätunf
# 43     42     12              42_std_zugwechsel_48_gültigkeitsdauer
# 44     43     13               43_fragen_umfrage_umfragen_erfassten
# 45     44      8                     44_hund_hunde_kosten_konduktor
# 46     45     10                 45_gebracht_ir37_pünktlich_service

# %%
# call function to create table and export excel
modelname = 'BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_Trends_June_2020'
directory_path = '../../exports/tables'

topicmodel_keywords = topic_model_top_10_keywords_export(model, modelname, directory_path)
topicmodel_keywords.sort_values('Count',ascending=False)
# Out:
#     Topic  Count  Count %            keyword 1         keyword 2  \
# 1       0    137     10.4            anschluss               zug
# 2       1     77      5.8                  app            ticket
# 4       3     63      4.8        maskenpflicht         einführen
# 3       2     61      4.6              tickets       spartickets
# 6       5     58      4.4                 züge       stosszeiten
# 5       4     53      4.0                   wc         toiletten
# 9       8     46      3.5               tragen            masken
# 7       6     39      2.9         sparbillette       sparbillete
# 15     14     38      2.9                knapp           minuten
# 10      9     38      2.9               preise             preis
# 8       7     35      2.6                sitze        sauberkeit
# 14     13     34      2.6             postauto         bahnfahrt
# 11     10     32      2.4  sicherheitspersonal  sicherheitsleute
# 26     25     29      2.2               corona          gefahren
# 20     19     29      2.2               corona              trug
# 12     11     29      2.2            zufrieden           gepasst
# 32     31     26      2.0                gerne         zufrieden
# 13     12     25      1.9                teuer             zonen
# 38     37     24      1.8               klasse             wagen
# 17     16     23      1.7                teuer                00
# 18     17     22      1.7          speisewagen           bedient
# 22     21     21      1.6        maskenpflicht                öv
# 24     23     21      1.6               bistro        informiert
# 25     24     21      1.6                wagen              laut
# 21     20     20      1.5          zugpersonal              ruhe
# 16     15     19      1.4              fahrrad           stromer
# 19     18     19      1.4          klimaanlage              kalt
# 35     34     19      1.4              bessere         verfügung
# 28     27     18      1.4                siehe        vorherigen
# 29     28     18      1.4       bushaltestelle              fuhr
# 36     35     17      1.3                 spät        verspätung
# 23     22     17      1.3                maske       eingehalten
# 27     26     16      1.2                laden             handy
# 39     38     16      1.2                 bike         plattform
# 31     30     15      1.1                  rhb          fahrplan
# 33     32     15      1.1                 wlan              wifi
# 34     33     15      1.1               häufig           raucher
# 40     39     15      1.1         verspätungen              takt
# 44     43     13      1.0               fragen           umfrage
# 41     40     13      1.0              perrons            mühsam
# 0      -1     13      1.0         angemessener            umfeld
# 30     29     13      1.0                türen            öffnen
# 37     36     12      0.9                   ic            bleibt
# 43     42     12      0.9                  std        zugwechsel
# 46     45     10      0.8             gebracht              ir37
# 42     41      9      0.7              machbar         schweinen
# 45     44      8      0.6                 hund             hunde
#
#             keyword 3         keyword 4            keyword 5  \
# 1          verbindung           direkte            umsteigen
# 2               lösen            kaufen               billet
# 4             pflicht     obligatorisch                   öv
# 3          tageskarte              velo                   ga
# 6               zügen          vorallem            schneller
# 5                 wcs          toilette           sauberkeit
# 9               maske        passagiere             schützen
# 7         sparbilette          anbieten            einführen
# 15             warten        verbindung                   21
# 10             senken             klass  leistungsverhältnis
# 8            reinigen              laut           verbessern
# 14              fahrt          busfahrt                kurze
# 11  sicherheitskräfte         bahnhöfen               abends
# 26                zug          angenehm          unglaublich
# 20     abstandsregeln             maske          coronavirus
# 12              happy          geklappt              optimal
# 32            angebot             fahre              ländern
# 13              preis              geld              billets
# 38           wünschen    klassenwechsel              dreckig
# 17            schüler         studenten                leute
# 18            gefehlt       gastronomie              service
# 22              zügen        zugwaggons            generelle
# 24         verspätete            abfuhr             fahrzeit
# 25           menschen           störend               extrem
# 21           genügend        freundlich              nötigen
# 16          fahrräder              bike                bikes
# 19              klima     funktionierte               sommer
# 35         veloplätze           stellen         gleiswechsel
# 28          kommentar       geschrieben              erwähnt
# 29              fährt          lugnorre             buslinie
# 36            abfahrt         verspätet                total
# 23      maskenpflicht            tragen              besteht
# 27             termin        smartphone           steckdosen
# 39               lift       kinderwagen                  eng
# 31              linie             busse              minuten
# 33           freesurf      rollmaterial     direktverbindung
# 34          rauchfrei            werfen           unangenehm
# 40           bisschen                ga              längere
# 44           umfragen         erfassten           beurteilen
# 41         einsteigen            plätze               defekt
# 0                traf           produkt           ungepflegt
# 30       automatische          berühren              einzige
# 37          littering     bahnanschluss        entschädigung
# 43                 48  gültigkeitsdauer              manuell
# 46          pünktlich           service                wagen
# 42                kfz        berspätunf             bahnhöfe
# 45             kosten         konduktor        einkaufswagen
#
#            keyword 6           keyword 7       keyword 8          keyword 9  \
# 1       verbindungen             strecke           gleis          swisspass
# 2           easyride            schalter          online           billette
# 4             masken              moment     durchsetzen         angebracht
# 3             kostet             bezahle            zone        einzelfahrt
# 6          richtigen                 zug     kinderwagen         durchsagen
# 5             defekt               liegt     geschlossen          verhalten
# 9             trugen                 zug        getragen           menschen
# 7           vermehrt              fehlen       verfügbar       umsteigezeit
# 15         wartezeit           rückfahrt              15                 30
# 10          belasten        billetpreise     attraktiver          leistungs
# 8              füsse      abfallbehälter     abfalleimer             abfall
# 14            fragen                 061     schifffahrt           relevant
# 11          sauberer               abend        reisende           security
# 26            zeiten               abend        gedrängt           verkürzt
# 20           wenigen                voll        getragen               fast
# 12             angst              sicher         perfekt             sauber
# 32          vorgehen      erstklasswagen           super              velos
# 13           verbund             strecke          billet               zone
# 38       stosszeiten               übrig        aufgrund              lässt
# 17              bahn              preise             chf           busfahrt
# 18       ankündigung                resp     geschlossen             bistro
# 22            vollen        schutzmasken         wichtig          begrüssen
# 24         ersatzzug               zuges  zugbegleiterin                lan
# 25           lüftung          reserviert    insbesondere          verbieten
# 21         angenehme               schön     anstrengend          sitzplatz
# 16        fahrrädern                ists       unterwegs         herzlichen
# 19              grad    aussentemperatur     installiert             wetter
# 35         aufgängen  2sicherheitskräfte    abgeschwächt        redundantes
# 28              text           vorherige           vorne          bemerkung
# 29           kollege        freundlicher    anschlussbus          baustelle
# 36                14                  11             zug      sehbehinderte
# 23                07               trägt          masken          unbedingt
# 27        realisiert           ungünstig         tochter           erreicht
# 39               rad           rollstuhl       rückwärts           handicap
# 31               vbl          riggisberg      busfahrten           verpasst
# 33            gratis                  08      anzubieten    aufsichtsperson
# 34       rauchverbot               orten   verschiedenen            rauchen
# 40     pünktlichkeit                1zug        wichtige                600
# 44           bezogen               daten   grundsätzlich      informationen
# 41        durchsagen              gebaut            leds  sitzmöglichkeiten
# 0          gesäubert            fahrstil         fahrers          erwartete
# 30             knopf               weder     automatisch              stört
# 37         touletten             strafen        warterei          gesperrte
# 43         angezeigt                juni            2020          angeboten
# 46           uraltem       verschmutzten     anständigen     grundsätzliche
# 42        alternativ             saubere         absolut      wünschenswert
# 45  kindertageskarte             siunden       reduziert    reiseteilnehmer
#
#          keyword 10
# 1            fahren
# 2         angezeigt
# 4         verzeigen
# 3            kaufen
# 6          manchmal
# 5         gereinigt
# 9        empfehlung
# 7         zeitpunkt
# 15       verspätung
# 10         tieferen
# 8               usw
# 14              top
# 11      beleuchtung
# 26          ungutes
# 20       schmutzige
# 12               10
# 32           thurbo
# 13       generalabo
# 38       sauberkeit
# 17          franken
# 18             dame
# 22         anstands
# 24              zug
# 25           stören
# 21          perfekt
# 16       veloabteil
# 19       ökologisch
# 35   zugänglichkeit
# 28      provokantes
# 29           nehmen
# 36        ärgerlich
# 23   unnötigerweise
# 27             akku
# 39  zugsbegleiterin
# 31         anpassen
# 33           kritik
# 34       schliessen
# 40     altersstufen
# 44          billett
# 41           bieler
# 0         einladend
# 30         angenehm
# 37    schulfreundin
# 43      ausgefallen
# 46         ausnahme
# 42
# 45       reinnehmen
