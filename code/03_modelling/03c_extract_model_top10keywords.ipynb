# %%
import sys
import os
sys.path.append(os.path.abspath('../')) ## needed to import the function.py file
from functions import *
# Out:
# 2023-03-15 10:13:33.364703: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
## Import dataframe
filelocation = '../../data/DataTextTrain'
data = pd.read_feather(filelocation)
data = data
docs = data["Kommentar"].values

# %%
#Select Topic model
topic_model = BERTopic.load("../../models/BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_merged.model")
model = topic_model

## Further reduce topics
#topic_model.reduce_topics(docs, nr_topics=16)

# %%
# call function to create table and export excel
modelname = 'BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_merged'
directory_path = '../../exports/tables'

topicmodel_keywords = topic_model_top_10_keywords_export(model, modelname, directory_path)
topicmodel_keywords.sort_values('Count',ascending=False)
# Out:
#     Topic  Count            keyword 1     keyword 2      keyword 3  \
# 0      -1  18819                  zug          züge         klasse
# 1       0   5879                  zug    verspätung        minuten
# 2       1   2999               klasse         wagen     sitzplätze
# 3       2   2457                   wc     toiletten     sauberkeit
# 4       3   2281                teuer        preise             ga
# 5       4   2215          kinderwagen        gepäck           hund
# 6       5   1604                  app        ticket          lösen
# 7       6   1579        maskenpflicht         maske         masken
# 8       7   1435            zufrieden         super       personal
# 9       8   1274                 kalt   klimaanlage    eingestellt
# 10      9   1049          speisewagen        kaffee         bistro
# 11     10    880                 wlan          wifi       internet
# 12     11    647  sicherheitspersonal         abend     sicherheit
# 13     12    547              rauchen   rauchverbot   telefonieren
# 14     13    518              umfrage        fragen       umfragen
# 15     14    505           durchsagen  lautsprecher  informationen
# 16     15    353         rollmaterial    bombardier         laptop
#
#       keyword 4     keyword 5          keyword 6      keyword 7     keyword 8  \
# 0           app         fahrt            strecke     verbindung        ticket
# 1     anschluss    verbindung          umsteigen   verspätungen  verbindungen
# 2   stosszeiten          züge          überfüllt            zug        plätze
# 3           wcs      toilette              zügen         defekt           zug
# 4         preis     günstiger            tickets     günstigere  sparbillette
# 5        koffer       fahrrad          fahrräder           velo          bike
# 6        mobile        billet          swisspass         kaufen       billett
# 7        tragen        corona              leute            zug      personen
# 8           job    freundlich                top        service       angebot
# 9        sommer           zug         temperatur          stark          warm
# 10     getränke       trinken                zug        bedient   geschlossen
# 11          zug    steckdosen              zügen         gratis         handy
# 12       abends         fühle  sicherheitskräfte         nachts     bahnhöfen
# 13      raucher      geraucht          bahnhöfen           laut       perrons
# 14        siehe    fragebogen              frage    beantworten     antworten
# 15     sprachen  verständlich                zug  anzeigetafeln         leise
# 16        türen      arbeiten               züge      einsetzen      besseres
#
#       keyword 9    keyword 10
# 0         wagen        fahren
# 1        warten        stunde
# 2          voll        wagons
# 3   geschlossen        sauber
# 4       schweiz        ticket
# 5         hunde         velos
# 6          easy  funktioniert
# 7      getragen     kontrolle
# 8       perfekt         gerne
# 9         heiss          grad
# 10      gipfeli       angebot
# 11         free      anbieten
# 12       sicher           zug
# 13        handy         laute
# 14    kommentar   beantwortet
# 15  information       ansagen
# 16       tische         dosto

# %%
data[data.yearmonth == '2020-06-01']
# Out:
#        participant_id     u_date  year  month  quarter  yearmonth yearquarter  \
# 57             380877 2020-06-25  2020      6        2 2020-06-01      2020Q2
# 118            375962 2020-06-06  2020      6        2 2020-06-01      2020Q2
# 178            374185 2020-06-01  2020      6        2 2020-06-01      2020Q2
# 240            373999 2020-06-03  2020      6        2 2020-06-01      2020Q2
# 245            374214 2020-06-01  2020      6        2 2020-06-01      2020Q2
# ...               ...        ...   ...    ...      ...        ...         ...
# 44853          374358 2020-06-02  2020      6        2 2020-06-01      2020Q2
# 44883          375032 2020-06-01  2020      6        2 2020-06-01      2020Q2
# 44897          377199 2020-06-09  2020      6        2 2020-06-01      2020Q2
# 44922          379157 2020-06-13  2020      6        2 2020-06-01      2020Q2
# 45025          380197 2020-06-25  2020      6        2 2020-06-01      2020Q2
#
#        season   yearseason                                          Kommentar  \
# 57     summer  2020-summer             Wieder vermehrt Sparbillette einführen
# 118    summer  2020-summer                       sbb soll mich in ruhe lassen
# 178    summer  2020-summer  Ich kann mir das zugfahren mit der sbb fast ni...
# 240    summer  2020-summer                          Pünklich, sauber, perfekt
# 245    summer  2020-summer  Reisen im ZVV-A-Welle Verbund sind leider sehr...
# ...       ...          ...                                                ...
# 44853  summer  2020-summer  Bei vollen Zügen sollte Maskenpflicht eingefüh...
# 44883  summer  2020-summer  Es wäre angebracht, eine Maskenpflicht einzufü...
# 44897  summer  2020-summer  ich finde wir haben nebst dem best ausgebauten...
# 44922  summer  2020-summer  ev. Zonenbeschreibung...Tram, Bus usw. was inb...
# 45025  summer  2020-summer  Fahre gerne mit der SBB, auch mit dem Velo, al...
#
#        ...  Kommentar_Tokens  Kommentar_Types  Kommentar_TTR  \
# 57     ...                 4                4     100.000000
# 118    ...                 6                6     100.000000
# 178    ...                41               38      92.682927
# 240    ...                 3                3     100.000000
# 245    ...                31               28      90.322581
# ...    ...               ...              ...            ...
# 44853  ...                 7                7     100.000000
# 44883  ...                 6                6     100.000000
# 44897  ...                26               24      92.307692
# 44922  ...                 9                9     100.000000
# 45025  ...                11               10      90.909091
#
#                                        text_preprocessed  \
# 57                       vermehrt sparbillette einführen
# 118                                                 ruhe
# 178    zugfahren fast leisten momentan spartickets gi...
# 240                              pünklich sauber perfekt
# 245    reisen zvv awelle verbund teuer zonen tageskar...
# ...                                                  ...
# 44853              vollen zügen maskenpflicht eingeführt
# 44883               angebracht maskenpflicht einzuführen
# 44897  nebst best ausgebauten öv netz abstand best fu...
# 44922   ev zonenbeschreibungtram usw inbegriffen billett
# 45025                            fahre gerne sbb velo ok
#
#                              text_preprocessed_tokenized  lemmatized  \
# 57                   [vermehrt, sparbillette, einführen]        None
# 118                                               [ruhe]        None
# 178    [zugfahren, fast, leisten, momentan, sparticke...        None
# 240                          [pünklich, sauber, perfekt]        None
# 245    [reisen, zvv, awelle, verbund, teuer, zonen, t...        None
# ...                                                  ...         ...
# 44853         [vollen, zügen, maskenpflicht, eingeführt]        None
# 44883           [angebracht, maskenpflicht, einzuführen]        None
# 44897  [nebst, best, ausgebauten, öv, netz, abstand, ...        None
# 44922  [ev, zonenbeschreibungtram, usw, inbegriffen, ...        None
# 45025                           [fahre, gerne, velo, ok]        None
#
#                                                    nouns  \
# 57                                        [sparbillette]
# 118                                               [ruhe]
# 178                [spartickets, franken, angebot, bitt]
# 240                                                   []
# 245    [reisen, zvv, verbund, zonen, tageskarte, tage...
# ...                                                  ...
# 44853                                            [zügen]
# 44883                                                 []
# 44897  [netz, abstand, best, netz, pünktlichkeit, sau...
# 44922                                          [billett]
# 45025                                             [velo]
#
#                            adjectives                                 verbs  \
# 57                                 []                           [einführen]
# 118                                []                                    []
# 178                                []  [zugfahren, leisten, erhalte, führt]
# 240                                []                                    []
# 245                          [awelle]                               [zahle]
# ...                               ...                                   ...
# 44853                        [vollen]                          [eingeführt]
# 44883                              []                         [einzuführen]
# 44897  [ausgebauten, funktionierende]                   [anbelangt, diesbb]
# 44922                              []                                    []
# 45025                              []                               [fahre]
#
#                               nouns_adjectives_and_verbs
# 57                             [sparbillette, einführen]
# 118                                               [ruhe]
# 178    [zugfahren, leisten, spartickets, erhalte, fra...
# 240                                                   []
# 245    [reisen, zvv, awelle, verbund, zonen, tageskar...
# ...                                                  ...
# 44853                        [vollen, zügen, eingeführt]
# 44883                                      [einzuführen]
# 44897  [ausgebauten, netz, abstand, best, funktionier...
# 44922                                          [billett]
# 45025                                      [fahre, velo]
#
# [926 rows x 59 columns]
