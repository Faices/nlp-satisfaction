# %%
import sys
import os
sys.path.append(os.path.abspath('../')) ## needed to import the function.py file
from functions import *
# Out:
# 2023-03-09 06:42:57.597668: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
## Import dataframe
filelocation = '../../data/DataTextTrain'
data = pd.read_feather(filelocation)
data = data
docs = data["Kommentar"].values

# %%
#Select Topic model
topic_model = BERTopic.load("../../models/BERTTopic_paraphrase-multilingual-MiniLM-L12-v2.model")
model = topic_model

## Further reduce topics
#topic_model.reduce_topics(docs, nr_topics=16)

# %%
# call function to create table and export excel
modelname = 'BERTTopic_paraphrase-multilingual-MiniLM-L12-v2'
directory_path = '../../exports/tables'

topicmodel_keywords = topic_model_top_10_keywords_export(model, modelname, directory_path)
topicmodel_keywords.sort_values('Count',ascending=False)
# Out:
#     Topic  Count     keyword 1      keyword 2    keyword 3   keyword 4  \
# 0      -1  18072           zug           züge      strecke      klasse
# 1       0   2231     umsteigen            zug   verspätung  verbindung
# 2       1   1785            wc      toiletten          wcs    toilette
# 3       2   1441         maske  maskenpflicht       masken      tragen
# 4       3   1274          kalt    klimaanlage  eingestellt      sommer
# ..    ...    ...           ...            ...          ...         ...
# 92     91     59        laptop       arbeiten       tische  steckdosen
# 93     92     59        gültig         ticket      gebucht     buchung
# 94     93     56           nöö
# 95     94     54           ski           skis       gepäck  snowboards
# 96     95     54  sparbillette         schade  sparbilette  sparbillet
#
#       keyword 5      keyword 6      keyword 7     keyword 8   keyword 9  \
# 0           app          fahrt     verbindung        ticket      fahren
# 1       minuten        strecke      anschluss      richtung      stunde
# 2        defekt    geschlossen     sauberkeit        sauber       zügen
# 3      getragen           nase      kontrolle         leute  kontrollen
# 4    temperatur           warm          heiss          grad       stark
# ..          ...            ...            ...           ...         ...
# 92      laptops          tisch  arbeitsplätze  fensterplatz     tischen
# 93        datum      rückfahrt       folgetag  retourbillet     tickets
# 94
# 95        skier  skiausrüstung       stauraum        koffer      winter
# 96  sparbillete        strecke           2018     verfügbar        2019
#
#      keyword 10
# 0         wagen
# 1          züge
# 2       saubere
# 3       trinken
# 4          kühl
# ..          ...
# 92           pc
# 93       gelöst
# 94
# 95    rucksäcke
# 96  sparbillett
#
# [97 rows x 12 columns]
