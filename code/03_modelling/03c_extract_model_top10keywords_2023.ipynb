# %%
import sys
import os
sys.path.append(os.path.abspath('../')) ## needed to import the function.py file
from functions import *
# Out:
# 2023-03-15 09:32:36.920607: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
## Import dataframe
filelocation = '../../data/DataText2023'
data = pd.read_feather(filelocation)
data = data
docs = data["Kommentar"].values

# %%
#Select Topic model
topic_model = BERTopic.load("../../models/BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_Trends_Q1_2023.model")
model = topic_model

## Further reduce topics
#topic_model.reduce_topics(docs, nr_topics=16)

# %%
model.get_topic_info()
# Out:
#     Topic  Count                                               Name
# 0      -1     18               -1_freitagen_draus_sonntagen_planbar
# 1       0    356                          0_zug_züge_überfüllt_voll
# 2       1    202         1_verbindung_strecke_verbindungen_fahrplan
# 3       2    124                   2_gepäck_leute_sitzplätze_sitzen
# 4       3    109           3_abends_sicherheitspersonal_abend_fühle
# 5       4    135                               4_01_billet_fahrt_23
# 6       5     86            5_siehe_pannen_bemerkungen_beschriftung
# 7       6     87                       6_kalt_winter_heizung_heizen
# 8       7     72                  7_laut_telefonieren_stört_ansagen
# 9       8     58            8_speisewagen_kaffee_gipfeli_restaurant
# 10      9     64                        9_ga_zufrieden_schön_events
# 11     10     61                            10_wc_toiletten_pro_wcs
# 12     11     90                      11_klasse_leer_arbeiten_wagen
# 13     12     57    12_zugbegleiter_personal_freundlich_freundliche
# 14     13     43                         13_wc_wcs_toiletten_papier
# 15     14     84            14_minuten_knapp_umsteigezeit_wartezeit
# 16     15     72          15_verspätungen_warten_minuten_verspätung
# 17     16     43  16_platzangebot_stosszeiten_veloplätze_anschlüsse
# 18     17     49             17_steckdosen_vorhanden_zügen_toilette
# 19     18     36           18_wlan_internet_wifi_internetverbindung
# 20     19     48           19_sauberkeit_verbessern_störungen_dosto
# 21     20     51                20_zufrieden_service_fragen_student
# 22     21     51                          21_wagons_wagen_bistro_ev
# 23     22     41                         22_ok_perfekt_okay_bestens
# 24     23     45                      23_app_billett_mobile_umfrage
# 25     24     39                       24_velo_sitze_velos_mitnahme
# 26     25     48  25_verspätungen_informieren_pünktlichkeit_info...
# 27     26     33               26_tickets_lösen_online_ticketpreise
# 28     27     64                    27_gefahren_via_anschluss_gleis
# 29     28     35                28_günstiger_bezahlt_fahrwangen_ahv
# 30     29     66                         29_app_easy_ride_swisspass
# 31     30     32                  30_preise_günstigere_preis_senken
# 32     31     49                     31_bus_lift_verpasst_anschluss
# 33     32     43               32_kinderwagen_kinder_familien_velos
# 34     33     24                  33_ski_skis_klasswagen_snowboards
# 35     34     40                    34_ga_halbtax_rabatt_fahrkarten
# 36     35     21          35_durchsetzen_rauchen_raucher_zigaretten

# %%
# call function to create table and export excel
modelname = 'BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_Trends_Q1_2023'
directory_path = '../../exports/tables'

topicmodel_keywords = topic_model_top_10_keywords_export(model, modelname, directory_path)
topicmodel_keywords.sort_values('Count',ascending=False)
# Out:
#     Topic  Count  Count %     keyword 1            keyword 2      keyword 3  \
# 1       0    356     13.8           zug                 züge      überfüllt
# 2       1    202      7.8    verbindung              strecke   verbindungen
# 5       4    135      5.2            01               billet          fahrt
# 3       2    124      4.8        gepäck                leute     sitzplätze
# 4       3    109      4.2        abends  sicherheitspersonal          abend
# 12     11     90      3.5        klasse                 leer       arbeiten
# 7       6     87      3.4          kalt               winter        heizung
# 6       5     86      3.3         siehe               pannen    bemerkungen
# 15     14     84      3.3       minuten                knapp   umsteigezeit
# 8       7     72      2.8          laut         telefonieren          stört
# 16     15     72      2.8  verspätungen               warten        minuten
# 30     29     66      2.6           app                 easy           ride
# 10      9     64      2.5            ga            zufrieden          schön
# 28     27     64      2.5      gefahren                  via      anschluss
# 11     10     61      2.4            wc            toiletten            pro
# 9       8     58      2.3   speisewagen               kaffee        gipfeli
# 13     12     57      2.2  zugbegleiter             personal     freundlich
# 22     21     51      2.0        wagons                wagen         bistro
# 21     20     51      2.0     zufrieden              service         fragen
# 18     17     49      1.9    steckdosen            vorhanden          zügen
# 32     31     49      1.9           bus                 lift       verpasst
# 20     19     48      1.9    sauberkeit           verbessern      störungen
# 26     25     48      1.9  verspätungen          informieren  pünktlichkeit
# 24     23     45      1.7           app              billett         mobile
# 33     32     43      1.7   kinderwagen               kinder       familien
# 17     16     43      1.7  platzangebot          stosszeiten     veloplätze
# 14     13     43      1.7            wc                  wcs      toiletten
# 23     22     41      1.6            ok              perfekt           okay
# 35     34     40      1.6            ga              halbtax         rabatt
# 25     24     39      1.5          velo                sitze          velos
# 19     18     36      1.4          wlan             internet           wifi
# 29     28     35      1.4     günstiger              bezahlt     fahrwangen
# 27     26     33      1.3       tickets                lösen         online
# 31     30     32      1.2        preise           günstigere          preis
# 34     33     24      0.9           ski                 skis     klasswagen
# 36     35     21      0.8   durchsetzen              rauchen        raucher
# 0      -1     18      0.7     freitagen                draus      sonntagen
#
#              keyword 4       keyword 5             keyword 6        keyword 7  \
# 1                 voll           wagen             umsteigen            gleis
# 2             fahrplan              30               direkte        umsteigen
# 5                   23            2023                gelöst           ticket
# 3               sitzen          koffer                 sitze           plätze
# 4                fühle      sicherheit                sicher           nachts
# 12               wagen       überfüllt                    kl               ga
# 7               heizen    temperaturen                sommer       temperatur
# 6         beschriftung             top                    49              tip
# 15           wartezeit  umsteigezeiten             anschluss       verspätung
# 8              ansagen         störend            durchsagen         manchmal
# 16          verspätung             zug                   mal        verpassen
# 30           swisspass          direkt             obermumpf     funktioniert
# 10              events   grundsätzlich               ausland           reisen
# 28               gleis              18                    16           fahren
# 11                 wcs          defekt              toilette            wagon
# 9           restaurant           kaffe              getränke      verpflegung
# 13         freundliche  zugbegleiterin             weiterhin     freundliches
# 22                  ev           wagon              anhängen      anschreiben
# 21             student      dankeschön        dienstleistung              job
# 18            toilette      einstecken                angabe        unmöglich
# 32           anschluss       umsteigen                 knapp            fehlt
# 20               dosto         gestank         pünktlichkeit       sicherheit
# 26       informationen     information               bessere        langsamer
# 24             umfrage        funktion               version           ticket
# 33               velos         kindern            einsteigen    familienwagen
# 17          anschlüsse   kommunikation  gruppenreservationen   veloparkplätze
# 14              papier     geschlossen              reinigen           öfters
# 23             bestens              io              geklappt          jüngere
# 35          fahrkarten        billiger               bezahle        studenten
# 25            mitnahme      sitzplätze          velomitnahme            nutze
# 19  internetverbindung        stabiles           günstigeres          empfang
# 29                 ahv      zahlstelle            gutscheine     sparbillette
# 27        ticketpreise     spartickets                corona        fahrkarte
# 31              senken      reduzieren           attraktiver         anpassen
# 34          snowboards          aussen            skiständer  veloreservation
# 36          zigaretten   anzeigetafeln                perron         bahnhöfe
# 0              planbar     zusatzstopp          optimiertere   notfallangebot
#
#              keyword 8         keyword 9         keyword 10
# 1                zuges            schade        stosszeiten
# 2                  zug         anschluss               züge
# 5           verspätung               zug                bus
# 3             reisende          stauraum            taschen
# 4    sicherheitskräfte         unterwegs            präsenz
# 12      klassenwechsel              voll               fast
# 7                 warm             zügen         unangenehm
# 6           vorherigen            tiptop          befragung
# 15            verpasst            stunde           bemessen
# 8            kopfhörer             essen         lautstärke
# 16              rennen         anschluss           manchmal
# 30            mehrmals            gelöst            buchung
# 10            bekommen              toll             kaufen
# 28              ticket              info                 15
# 11             anlagen      geschlossene           geöffnet
# 9                essen         bestellen            bedient
# 13  zugbegleitpersonal        zugbegleit  zugbegleiterinnen
# 22          restaurant         durchgang        bistrowagen
# 21     zuverlässigkeit             liebe      pünktlichkeit
# 18                  02       information       familienzone
# 32               busse         reichenau           fahrplan
# 20                  fv          reinigen            überall
# 26         frühzeitige        deutlicher        kurzfristig
# 24             gekauft             lösen          automaten
# 33                raum             schön           senioren
# 17            abteilen           bessere           empfinde
# 14             saubere          generell           manchmal
# 23                 tür             gibts              komme
# 35               teuer           angebot          vergleich
# 25               gerne           zuwenig             arbeit
# 19               zügen         touristen            angebot
# 29            vermisse              geld              händi
# 27          günstigere           automat         ticketkauf
# 31            angebote         günstiger           anbieten
# 34           snowboard  rückreiseverkehr          angehängt
# 36         anordnungen             uhren          rauchfrei
# 0            wildtiere        fahrgefühl        umleitungen
