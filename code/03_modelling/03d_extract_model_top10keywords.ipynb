# %%
import sys
import os
sys.path.append(os.path.abspath('../')) ## needed to import the function.py file
from functions import *

# %%
#Select Topic model
topic_model = BERTopic.load("../../models/BERTTopic_all-MiniLM-L6-v2_normalized50T.model")
model = topic_model
modelname = 'BERTTopic_all-MiniLM-L6-v2_normalized50T'
directory_path = '../../exports/tables'

# call function to create table and export excel
topicmodel_keywords = topic_model_top_10_keywords_export(model, modelname, directory_path)
topicmodel_keywords
# Out:
#     Topic  Count            keyword 1         keyword 2          keyword 3  \
# 0      -1  12506                  zug              züge            minuten
# 1       0  15586                  zug        verspätung            minuten
# 2       1   2124               klasse             wagen     klassenwechsel
# 3       2   1755                  app              wlan               wifi
# 4       3   1570               ticket           tickets                app
# 5       4    968          stosszeiten        steckdosen           strecken
# 6       5    565         sparbillette       spartickets        sparbillett
# 7       6    492        pünktlichkeit         pünktlich        pünktlicher
# 8       7    478  sicherheitspersonal      verbindungen  sicherheitskräfte
# 9       8    443               wagons             wagon             klasse
# 10      9    427               billet           billett           billette
# 11     10    419           sauberkeit                wc             sauber
# 12     11    411               gepäck      gepäckstücke           stauraum
# 13     12    386         platzangebot        sitzplätze             plätze
# 14     13    362               reisen             reise           reisende
# 15     14    354                 ride              easy               bike
# 16     15    335                wagen          anhängen              wägen
# 17     16    332         rollmaterial         rollstuhl           besseres
# 18     17    326               bistro       geschlossen            bedient
# 19     18    318            swisspass          anpassen               pass
# 20     19    315          speisewagen           bedient       kontrolleure
# 21     20    284            zufrieden       zugpersonal       zugbegleiter
# 22     21    253            günstiger        günstigere             preise
# 23     22    252          informieren     informationen        information
# 24     23    251            fahrräder     familienwagen            fahrrad
# 25     24    245            ruhewagen         rückfahrt        ruheabteile
# 26     25    235               corona             covid             zeiten
# 27     26    221         telefonieren              laut        telefoniert
# 28     27    218                  nil            nathan              afdfd
# 29     28    209          abfalleimer            abfall     abfallbehälter
# 30     29    207                 halt       haltestelle          verlangen
# 31     30    196             personal      freundliches         freundlich
# 32     31    173        doppelstöcker  doppelstockwagen        doppelstock
# 33     32    169              raucher       rauchverbot            rauchen
# 34     33    167               perron           perrons           anzeigen
# 35     34    159        velotransport         transport               velo
# 36     35    159                zonen              zone                110
# 37     36    144           bombardier           stadler               züge
# 38     37    139          kinderwagen            kinder               kind
# 39     38    121           südostbahn         forchbahn        zentralbahn
# 40     39     98             getränke           getränk          getränken
# 41     40     98                 tram               the              trams
# 42     41     95                  tip               top             tiptop
# 43     42     92                handy        steckdosen             handys
# 44     43     81                  ski              skis             gepäck
# 45     44     70              lüftung              luft            stickig
# 46     45     64              bilette            bilett              bilet
# 47     46     61         retourbillet     retourbillett             gültig
# 48     47     54                   s3                s9                 s6
# 49     48     54              minibar            kaffee           minibars
#
#           keyword 4         keyword 5                   keyword 6  \
# 0        verspätung             fahrt                  verbindung
# 1              züge             maske                       fahrt
# 2             klass       klimaanlage                      koffer
# 3          internet            mobile                      laptop
# 4       reservation             lösen                      kaufen
# 5           strecke              züge                    postauto
# 6       sparbilette          anbieten                 sparbillete
# 7        verbessern        sauberkeit                        züge
# 8        sicherheit      zugspersonal                     präsenz
# 9       stosszeiten          anhängen                       klass
# 10            lösen          billiger                         app
# 11          saubere          sauberer                 schifffahrt
# 12        verstauen     gepäckablagen                 reisegepäck
# 13        sitzplatz        reserviert                reservierten
# 14        reisenden               zug                    angenehm
# 15            bikes          easyride                  parkplätze
# 16           wagens            wägeli                          wc
# 17    rollmaterials         einsetzen                     neueres
# 18      bistrowagen   restaurantwagen                 restaurants
# 19       passagiere       juniorkarte                         app
# 20       kontrollen         kontrolle                 geschlossen
# 21    zugbegleitung      unfreundlich                  freundlich
# 22               ga          anbieten                    angebote
# 23          bessere         störungen                verspätungen
# 24         familien       kinderwagen              familienabteil
# 25       ruheabteil         rückreise                        ruhe
# 26     coronazeiten                19                        züge
# 27          telefon           störend            telefongespräche
# 28               ok               non                  dankeschön
# 29      abfallkübel           ausfall                      leeren
# 30     haltestellen              hält                       knopf
# 31       sicherheit         personals                 kompetentes
# 32           oberen  doppelstockzügen             doppelstockzüge
# 33     raucherzonen         bahnhöfen                    geraucht
# 34          anzeige            sektor           sitzgelegenheiten
# 35            velos    transportieren  velotransportmöglichkeiten
# 36  anschlussbillet               abo                     doppelt
# 37             rail             dosto              schüttelbecher
# 38       einsteigen             velos                    einstieg
# 39       endbahnhof        rutschbahn                   eisenbahn
# 40           snacks   getränkeservice                 speisewagen
# 41              app          sonceboz                          nr
# 42         tipptopp              tipp                      niveau
# 43            laden       handyverbot                    aufladen
# 44       snowboards             skier                       velos
# 45           lüften          stickige                abgestandene
# 46              app        bilettkauf                      online
# 47           retour       retourfahrt                       lösen
# 48              s12                s7                         s11
# 49              bar              mini                 speisewagen
#
#          keyword 7         keyword 8          keyword 9  \
# 0              app           strecke                 wc
# 1    maskenpflicht        verbindung          umsteigen
# 2             kalt                kl                 ga
# 3     funktioniert          arbeiten              zügen
# 4             velo      ticketpreise             online
# 5       sitzplätze             zügen       kurzstrecken
# 6       sparbillet        sparticket             schade
# 7       pünktliche      pünktlichere    zuverlässigkeit
# 8            abend            abends         verbindung
# 9           stehen        sitzplätze          überfüllt
# 10           teuer           billets             gelöst
# 11             wcs             zügen               züge
# 12        grössere        sitzplätze       gepäckablage
# 13           knapp            sitzen           personen
# 14       reisezeit           strecke           personen
# 15    funktioniert               app               velo
# 16           alten       stosszeiten              vorne
# 17      rolltreppe        moderneres            strecke
# 18     speisewagen          catering             kaffee
# 19           karte             login             online
# 20     kontrolleur     kontrollieren       kontrolliert
# 21     hilfsbereit    zugbegleiterin            präsenz
# 22         billete            tarife        günstigeres
# 23            info             infos         informiert
# 24          kinder        fahrrädern      fahrradplätze
# 25          klasse          ruhezone          einführen
# 26           virus           waggons      maskenpflicht
# 27       ruhewagen             laute         telefonate
# 28          denken
# 29             zug         entsorgen          ausfallen
# 30     bergstrecke                wc           sauberer
# 31       weiterhin       hilfsbereit          anstellen
# 32           alten    doppelstöckige               züge
# 33         perrons      nichtraucher  zigarettenstummel
# 34      durchsagen     wartehäuschen         einsteigen
# 35     kinderwagen  transportpolizei              there
# 36             app          zonenabo                zvv
# 37     fahrkomfort          arbeiten                zug
# 38    kinderabteil         unterwegs        kinderwägen
# 39  eisenbahnwagen     familienwagen                 12
# 40          wägeli    getränkewägeli             bistro
# 41      verbindung          gefahren          angezeigt
# 42            topp           service       hinterlassen
# 43           händy         gespräche          verbieten
# 44        stauraum            koffer             winter
# 45      unangenehm           luftzug              zügen
# 46           lösen            gelöst         überteuert
# 47  retourbillette            gelöst         gültigkeit
# 48             s21                s8         verbindung
# 49       einführen          vermisse         minimieren
#
#                 keyword 10
# 0             verbindungen
# 1                     bahn
# 2                     voll
# 3               verbindung
# 4                  gekauft
# 5                  längere
# 6                  strecke
# 7                 ankommen
# 8                  bessere
# 9                sitzplatz
# 10                  kaufen
# 11                     zug
# 12                  sitzen
# 13                   wagen
# 14                    züge
# 15                    rail
# 16               einsetzen
# 17                rollator
# 18                  schade
# 19                  zeigen
# 20                 betrieb
# 21      zugbegleitpersonal
# 22                günstige
# 23              verspätung
# 24                 kindern
# 25               ruhezonen
# 26             stosszeiten
# 27                   stört
# 28
# 29             sitzplätzen
# 30             schnellzüge
# 31                genügend
# 32         doppelstöckigen
# 33                   rauch
# 34                     zug
# 35  transportmöglichkeiten
# 36                  billet
# 37                   alten
# 38                    züge
# 39                 strecke
# 40                   snack
# 41                richtung
# 42              pünktliche
# 43               steckdose
# 44           skiausrüstung
# 45            luftqualität
# 46                   teuer
# 47                folgetag
# 48               anschluss
# 49                 alleine
