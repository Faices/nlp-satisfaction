# %%
import sys
import os
sys.path.append(os.path.abspath('../')) ## needed to import the function.py file
from functions import *
# Out:
# 2023-03-02 08:06:08.169069: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
## Import dataframe
filelocation = '../../data/DataTextTrain'
data = pd.read_feather(filelocation)
docs = data["Kommentar"].to_list()
timestamps = data.u_date.to_list()

filelocation = '../../data/DataTextValidation'
data_val = pd.read_feather(filelocation)
docs_val = data_val["Kommentar"].to_list()
timestamps = data_val.u_date.to_list()

# %%
topic_model_1 = BERTopic.load("../../models/BERTTopic_all-distilroberta-v1_outliers_reduced_40T.model")
topic_model_2 = BERTopic.load("../../models/BERTTopic_all-MiniLM-L6-v2_outliers_reduced_40T.model")
topic_model_3 = BERTopic.load("../../models/BERTTopic_all-MiniLM-L12-v2_outliers_reduced_40T.model")
topic_model_4 = BERTopic.load("../../models/BERTTopic_all-mpnet-base-v2_outliers_reduced_40T.model")
topic_model_5 = BERTopic.load("../../models/BERTTopic_paraphrase-MiniLM-L3-v2_outliers_reduced_40T.model")
topic_model_6 = BERTopic.load("../../models/BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_outliers_reduced_40T.model")
# topic_model_1.reduce_topics(docs, nr_topics=40)
# topic_model_2.reduce_topics(docs, nr_topics=40)
# topic_model_3.reduce_topics(docs, nr_topics=40)
# topic_model_4.reduce_topics(docs, nr_topics=40)
# topic_model_5.reduce_topics(docs, nr_topics=40)
# topic_model_6.reduce_topics(docs, nr_topics=40)

# %%
topic_model_6.get_topic_info()
# Out:
#     Topic  Count                                               Name
# 0      -1    334  -1_velofreundlicher_2sicherheitskräfte_kiosk9_...
# 1       0  17903                     0_zug_verspätung_minuten_fahrt
# 2       1   2178                          1_app_ticket_lösen_billet
# 3       2   1854                        2_wc_toiletten_wcs_toilette
# 4       3   1695                  3_wagen_kinderwagen_wagons_klasse
# 5       4   1648                   4_postauto_busse_anschluss_fährt
# 6       5   1612  5_verspätungen_pünktlichkeit_pünktlich_verspätung
# 7       6   1593                  6_züge_zügen_sauberkeit_überfüllt
# 8       7   1527                7_maskenpflicht_maske_masken_tragen
# 9       8   1392              8_klimaanlage_kalt_sommer_eingestellt
# 10      9   1358               9_klasse_klassenwechsel_studenten_ga
# 11     10   1045     10_abend_abends_sicherheit_sicherheitspersonal
# 12     11    895               11_sitzplätze_velo_reservation_velos
# ...

# %% [markdown]
# ### Own Embeddings test

# %%
# import tensorflow
# import tensorflow_hub as hub

# #load the universal sentence encoder model
# use4 = hub.load("https://tfhub.dev/google/universal-sentence-encoder/4")

# #generate embeddings
# use4_embeddings = use4(docs)
# use= np.array(use4_embeddings)

# topic_model_6 = topic_model_2

# #pass the embeddings into BERTopic
# topic_model_6.fit_transform(docs, use)

# #get topic info
# topic_model_6.get_topic_info()

# %% [markdown]
# ## Model 1: Spacy Embeddings

# %%
topic_model_2.get_topic_info()
# Out:
#      Topic  Count                                          Name
# 0       -1  13222          -1_zug_minuten_verspätung_verbindung
# 1        0   1697              0_bahnhöfen_bahn_bahnhöfe_bahnen
# 2        1   1438           1_klasse_klassenwechsel_klass_wagen
# 3        2   1380                      2_zug_mal_fahren_minuten
# 4        3   1327                    3_ticket_tickets_app_lösen
# ..     ...    ...                                           ...
# 130    129     56    129_sitzplätze_sorgen_sitzplätzsn_mitfahrt
# 131    130     56            130_anpassen_preise_preis_leistung
# 132    131     56      131_zugbegleitern_25_person_bestimmungen
# 133    132     56            132_spät_spätere_stunde_absperrung
# 134    133     51  133_gutschein_gutscheine_einlösen_restbetrag
#
# [135 rows x 3 columns]

# %%
# # Transform your documents to topics and their probabilities
# topics, probs = topic_model_2.transform(docs)

# %%
# Reduce outliers using the `c-tf-idf` strategy
new_topics = topic_model_2.reduce_outliers(docs, topics, strategy="c-tf-idf")

# %%
# Update the Topic Model with new topic assignment
topic_model_2.update_topics(docs, topics=new_topics)

# %%
topic_model_2.get_topic_info()
# Out:
#      Topic  Count                                          Name
# 0       -1  13222          -1_zug_minuten_verspätung_verbindung
# 1        0   1697              0_bahnhöfen_bahn_bahnhöfe_bahnen
# 2        1   1438           1_klasse_klassenwechsel_klass_wagen
# 3        2   1380                      2_zug_mal_fahren_minuten
# 4        3   1327                    3_ticket_tickets_app_lösen
# ..     ...    ...                                           ...
# 130    129     56    129_sitzplätze_sorgen_sitzplätzsn_mitfahrt
# 131    130     56            130_anpassen_preise_preis_leistung
# 132    131     56      131_zugbegleitern_25_person_bestimmungen
# 133    132     56            132_spät_spätere_stunde_absperrung
# 134    133     51  133_gutschein_gutscheine_einlösen_restbetrag
#
# [135 rows x 3 columns]

# %%
topic_model_2.visualize_hierarchy()

# %%
topic_model_3.get_topic(0)
# Out:
# [('billett', 0.044607234316527807),
#  ('billet', 0.04261845586639286),
#  ('billette', 0.026215449400775886),
#  ('lösen', 0.02540674926165964),
#  ('app', 0.01988633415265387),
#  ('billiger', 0.016775372805182424),
#  ('gelöst', 0.016529140385594374),
#  ('kaufen', 0.015813664875873462),
#  ('hund', 0.011941722022428628),
#  ('automaten', 0.01109362179621451)]

# %%
topic_model_3.get_document_info(docs)
# Out:
#                                                 Document  Topic  \
# 0      Sie haben sehr nettes Zugbegleiter Personal. D...     18
# 1      Pünktlichkeit im Berufsverkehr ist dringend zu...     17
# 2                         Klimaanlage/Lüftung verbessern     27
# 3                         Billete im Bahnersatzbus lösen     33
# 4      Sauberkeit generell inkl. WC / regelmässiger k...      8
# ...                                                  ...    ...
# 45036  Schnellere Verbindung von Zürich nach St. Gall...     -1
# 45037              Ein Morgenstern ist eine schöne Sache     -1
# 45038  Beibehaltung von Turgi als wichtiger Zubringer...     -1
# 45039  Zu wenig Wagen, Sitzplätze. Zuwenig Zugverbind...     -1
# 45040  unbedingt SBB FREE besser ausbauen, damit auch...      0
#
#                                                     Name  \
# 0               18_toiletten_toilette_defekt_geschlossen
# 1      17_pünktlichkeit_pünktlich_pünktlicher_verbessern
# ...

# %%
topic_model_2.get_params()
# Out:
# {'calculate_probabilities': False,
#  'ctfidf_model': ClassTfidfTransformer(),
#  'embedding_model': <bertopic.backend._sentencetransformers.SentenceTransformerBackend at 0x7fd8ac1bef40>,
#  'hdbscan_model': HDBSCAN(min_cluster_size=50, prediction_data=True),
#  'language': None,
#  'low_memory': False,
#  'min_topic_size': 50,
#  'n_gram_range': (1, 1),
#  'nr_topics': None,
#  'representation_model': None,
#  'seed_topic_list': None,
#  'top_n_words': 10,
#  'umap_model': UMAP(angular_rp_forest=True, low_memory=False, metric='cosine', min_dist=0.0, n_components=5, tqdm_kwds={'bar_format': '{desc}: {percentage:3.0f}%| {bar} {n_fmt}/{total_fmt} [{elapsed}]', 'desc': 'Epochs completed', 'disable': True}),
#  'vectorizer_model': CountVectorizer(stop_words=['aber', 'acht', 'aehnlich', 'ähnlich', 'allein',
#                              'allem', 'aller', 'allerdings', 'alles', 'allg',
#                              'allgemein', 'ander', 'andere', 'anderem',
# ...

# %%
topic_model_2.visualize_topics()

# %%
topic_model_2.reduce_topics(docs, nr_topics=20)
topic_model_2.visualize_hierarchy()
