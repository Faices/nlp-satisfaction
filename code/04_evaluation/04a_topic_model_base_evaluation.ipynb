# %%
import sys
import os
sys.path.append(os.path.abspath('../')) ## needed to import the function.py file
from functions import *
# Out:
# 2023-03-07 16:43:00.295579: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
## Import dataframe
filelocation = '../../data/DataTextTrain'
data = pd.read_feather(filelocation)
data = data
docs = data["Kommentar"].values

# %%
len(docs)
# Out:
# 45041

# %%
topic_model_1 = BERTopic.load("../../models/BERTTopic_all-distilroberta-v1.model")
topic_model_2 = BERTopic.load("../../models/BERTTopic_all-MiniLM-L6-v2.model")
topic_model_3 = BERTopic.load("../../models/BERTTopic_all-MiniLM-L12-v2.model")
topic_model_4 = BERTopic.load("../../models/BERTTopic_all-mpnet-base-v2.model")
topic_model_5 = BERTopic.load("../../models/BERTTopic_paraphrase-MiniLM-L3-v2.model")
topic_model_6 = BERTopic.load("../../models/BERTTopic_paraphrase-multilingual-MiniLM-L12-v2.model")

# %%
print(len(topic_model_1.get_topic_freq())-1)
print(len(topic_model_2.get_topic_freq())-1)
print(len(topic_model_3.get_topic_freq())-1)
print(len(topic_model_4.get_topic_freq())-1)
print(len(topic_model_5.get_topic_freq())-1)
print(len(topic_model_6.get_topic_freq())-1)
# Out:
# 117
# 139
# 128
# 133
# 65
# 96

# %%
topic_model_1.reduce_topics(docs, nr_topics=40)
topic_model_2.reduce_topics(docs, nr_topics=40)
topic_model_3.reduce_topics(docs, nr_topics=40)
topic_model_4.reduce_topics(docs, nr_topics=40)
topic_model_5.reduce_topics(docs, nr_topics=40)
topic_model_6.reduce_topics(docs, nr_topics=40)
topic_model_1.save('../../models/BERTTopic_all-distilroberta-v1_40T.model')
topic_model_2.save('../../models/BERTTopic_all-MiniLM-L6-v2_40T.model')
topic_model_3.save('../../models/BERTTopic_all-MiniLM-L12-v2_40T.model')
topic_model_4.save('../../models/BERTTopic_all-mpnet-base-v2_40T.model')
topic_model_5.save('../../models/BERTTopic_paraphrase-MiniLM-L3-v2_40T.model')
topic_model_6.save('../../models/BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_40T.model')

# %%
bert_models_normalized = [
    "BERTTopic_all-distilroberta-v1_40T.model",
    "BERTTopic_all-MiniLM-L6-v2_40T.model",
    "BERTTopic_all-MiniLM-L12-v2_40T.model",
    "BERTTopic_all-mpnet-base-v2_40T.model",
    "BERTTopic_paraphrase-MiniLM-L3-v2_40T.model",
    "BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_40T.model"
    ]

# %%
bert_models = [
    "BERTTopic_all-distilroberta-v1.model",
    "BERTTopic_all-MiniLM-L6-v2.model",
    "BERTTopic_all-MiniLM-L12-v2.model",
    "BERTTopic_all-mpnet-base-v2.model",
    "BERTTopic_paraphrase-MiniLM-L3-v2.model",
    "BERTTopic_paraphrase-multilingual-MiniLM-L12-v2.model"
    ]

# %% [markdown]
# ## Coherence-Score

# %% [markdown]
# ## Scores Berechnen

# %%
model_base_path = "../../models/"

# %%
u_mass_scores = compute_coherence_scores(documents=docs, bert_models=bert_models_normalized, coherence_method="u_mass", path=model_base_path)
u_mass_scores.to_csv(f"../../exports/tables/coherence_scores_u_mass.csv")
u_mass_scores
# Out:
# /Users/dom/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Users/dom/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# BERT Model BERTTopic_all-distilroberta-v1_40T.model: nan
# BERT Model BERTTopic_all-MiniLM-L6-v2_40T.model: -0.5770293929546888
# BERT Model BERTTopic_all-MiniLM-L12-v2_40T.model: -0.4809028426546917
# /Users/dom/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Users/dom/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# ...

# %%
c_v_scores = compute_coherence_scores(documents=docs, bert_models=bert_models_normalized, coherence_method="c_v", path=model_base_path)
c_v_scores.to_csv(f"../../exports/tables/coherence_scores_c_v.csv")
c_v_scores
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# ...

# %% [markdown]
# ## Reduce Outlies with c-TF-IDF

# %%
topic_model_1 = BERTopic.load("../../models/BERTTopic_all-distilroberta-v1_outliers_reduced.model")
topic_model_2 = BERTopic.load("../../models/BERTTopic_all-MiniLM-L6-v2_outliers_reduced.model")
topic_model_3 = BERTopic.load("../../models/BERTTopic_all-MiniLM-L12-v2_outliers_reduced.model")
topic_model_4 = BERTopic.load("../../models/BERTTopic_all-mpnet-base-v2_outliers_reduced.model")
topic_model_5 = BERTopic.load("../../models/BERTTopic_paraphrase-MiniLM-L3-v2_outliers_reduced.model")
topic_model_6 = BERTopic.load("../../models/BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_outliers_reduced.model")

# %%
topic_model_1.reduce_topics(docs, nr_topics=40)
topic_model_2.reduce_topics(docs, nr_topics=40)
topic_model_3.reduce_topics(docs, nr_topics=40)
topic_model_4.reduce_topics(docs, nr_topics=40)
topic_model_5.reduce_topics(docs, nr_topics=40)
topic_model_6.reduce_topics(docs, nr_topics=40)
topic_model_1.save('../../models/BERTTopic_all-distilroberta-v1_outliers_reduced_40T.model')
topic_model_2.save('../../models/BERTTopic_all-MiniLM-L6-v2_outliers_reduced_40T.model')
topic_model_3.save('../../models/BERTTopic_all-MiniLM-L12-v2_outliers_reduced_40T.model')
topic_model_4.save('../../models/BERTTopic_all-mpnet-base-v2_outliers_reduced_40T.model')
topic_model_5.save('../../models/BERTTopic_paraphrase-MiniLM-L3-v2_outliers_reduced_40T.model')
topic_model_6.save('../../models/BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_outliers_reduced_40T.model')

# %%
bert_models = [
    "BERTTopic_all-distilroberta-v1_outliers_reduced_40T.model",
    "BERTTopic_all-MiniLM-L6-v2_outliers_reduced_40T.model",
    "BERTTopic_all-MiniLM-L12-v2_outliers_reduced_40T.model",
    "BERTTopic_all-mpnet-base-v2_outliers_reduced_40T.model",
    "BERTTopic_paraphrase-MiniLM-L3-v2_outliers_reduced_40T.model",
    "BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_outliers_reduced_40T.model"
    ]

# %%
u_mass_scores = compute_coherence_scores(documents=docs, bert_models=bert_models, coherence_method="u_mass", path=model_base_path)
u_mass_scores.to_csv(f"../../exports/tables/coherence_scores_u_mass.csv")
u_mass_scores
# Out:
# BERT Model BERTTopic_all-distilroberta-v1_outliers_reduced_40T.model: -0.4700842758842805
# BERT Model BERTTopic_all-MiniLM-L6-v2_outliers_reduced_40T.model: -0.5558256641501602
# BERT Model BERTTopic_all-MiniLM-L12-v2_outliers_reduced_40T.model: -0.41034314399478106
# BERT Model BERTTopic_all-mpnet-base-v2_outliers_reduced_40T.model: -0.5039106034679609
# BERT Model BERTTopic_paraphrase-MiniLM-L3-v2_outliers_reduced_40T.model: -0.323173146417881
# BERT Model BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_outliers_reduced_40T.model: -0.43886239729576204
# BERTTopic_all-distilroberta-v1_outliers_reduced_40T.model                    -0.470084
# BERTTopic_all-MiniLM-L6-v2_outliers_reduced_40T.model                        -0.555826
# BERTTopic_all-MiniLM-L12-v2_outliers_reduced_40T.model                       -0.410343
# BERTTopic_all-mpnet-base-v2_outliers_reduced_40T.model                       -0.503911
# ...

# %%
c_v_scores = compute_coherence_scores(documents=docs, bert_models=bert_models, coherence_method="c_v", path=model_base_path)
c_v_scores.to_csv(f"../../exports/tables/coherence_scores_c_v.csv")
c_v_scores
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# ...
