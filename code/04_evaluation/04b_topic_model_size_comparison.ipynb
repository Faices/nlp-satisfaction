# %%
import sys
import os
sys.path.append(os.path.abspath('../')) ## needed to import the function.py file
from functions import *
import plotly.express as px
import plotly.io as pio

## plot settings
color_discrete_sequence = color_discrete_kuzu #imported from globalvars.py
template = template ##imported from globalvars.py

# %%
## Import dataframe
filelocation = '../../data/DataTextTrain'
data = pd.read_feather(filelocation)
docs = data["Kommentar"].values

# %%
# Load the orginal Model
topic_model = BERTopic.load("../../models/BERTTopic_paraphrase-multilingual-MiniLM-L12-v2.model")

# %%
# set name of base model
modelname = 'BERTTopic_paraphrase-multilingual-MiniLM-L12-v2'

# set directory to save generated models
savepath = '../../models/submodels/'

def save_model_versions(model, modelname,path):
    modelnames =[]
    modelname = modelname
    for i in range(96,2,-2):
        reduced_model = model.reduce_topics(docs, nr_topics=i)
        reduced_model_name = modelname + '_'+str(i) +'T.model'
        reduced_model.save(path + reduced_model_name)
        modelnames.append(reduced_model_name)
    return modelnames

# %%
modellist = save_model_versions(topic_model, modelname,savepath)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 modellist = save_model_versions(topic_model, modelname,savepath)
#
# Cell In[13], line 11, in save_model_versions(model, modelname, path)
#       9 modelname = modelname
#      10 for i in range(96,2,-2):
# ---> 11     reduced_model = model.reduce_topics(docs, nr_topics=i)
#      12     reduced_model_name = modelname + '_'+str(i) +'T.model'
#      13     reduced_model.save(path + reduced_model_name)
#
# File ~/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/bertopic/_bertopic.py:1860, in BERTopic.reduce_topics(self, docs, nr_topics)
#    1857 documents = pd.DataFrame({"Document": docs, "Topic": self.topics_})
#    1859 # Reduce number of topics
# -> 1860 documents = self._reduce_topics(documents)
#    1861 self._merged_topics = None
#    1862 self._save_representative_docs(documents)
#
# File ~/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/bertopic/_bertopic.py:3191, in BERTopic._reduce_topics(self, documents)
#    3189 if isinstance(self.nr_topics, int):
#    3190     if self.nr_topics < initial_nr_topics:
# -> 3191         documents = self._reduce_to_n_topics(documents)
#    3192 elif isinstance(self.nr_topics, str):
#    3193     documents = self._auto_reduce_topics(documents)
#
# File ~/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/bertopic/_bertopic.py:3235, in BERTopic._reduce_to_n_topics(self, documents)
#    3233 # Update representations
#    3234 documents = self._sort_mappings_by_frequency(documents)
# -> 3235 self._extract_topics(documents)
#    3236 self._update_topic_size(documents)
#    3237 return documents
#
# File ~/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/bertopic/_bertopic.py:2951, in BERTopic._extract_topics(self, documents)
#    2949 self.c_tf_idf_, words = self._c_tf_idf(documents_per_topic)
#    2950 self.topic_representations_ = self._extract_words_per_topic(words, documents)
# -> 2951 self._create_topic_vectors()
#    2952 self.topic_labels_ = {key: f"{key}_" + "_".join([word[0] for word in values[:4]])
#    2953                       for key, values in
#    2954                       self.topic_representations_.items()}
#
# File ~/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/bertopic/_bertopic.py:3051, in BERTopic._create_topic_vectors(self)
#    3049 topic_words = [self.get_topic(topic) for topic in topic_list]
#    3050 topic_words = [word[0] for topic in topic_words for word in topic]
# -> 3051 embeddings = self._extract_embeddings(topic_words,
#    3052                                       method="word",
#    3053                                       verbose=False)
#    3055 # Take the weighted average of word embeddings in a topic based on their c-TF-IDF value
#    3056 # The embeddings var is a single numpy matrix and therefore slicing is necessary to
#    3057 # access the words per topic
#    3058 topic_embeddings = []
#
# File ~/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/bertopic/_bertopic.py:2795, in BERTopic._extract_embeddings(self, documents, method, verbose)
#    2792     documents = [documents]
#    2794 if method == "word":
# -> 2795     embeddings = self.embedding_model.embed_words(documents, verbose)
#    2796 elif method == "document":
#    2797     embeddings = self.embedding_model.embed_documents(documents, verbose)
#
# File ~/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/bertopic/backend/_base.py:53, in BaseEmbedder.embed_words(self, words, verbose)
#      38 def embed_words(self,
#      39                 words: List[str],
#      40                 verbose: bool = False) -> np.ndarray:
#      41     """ Embed a list of n words into an n-dimensional
#      42     matrix of embeddings
#      43
#    (...)
#      51
#      52     """
# ---> 53     return self.embed(words, verbose)
#
# File ~/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/bertopic/backend/_sentencetransformers.py:63, in SentenceTransformerBackend.embed(self, documents, verbose)
#      49 def embed(self,
#      50           documents: List[str],
#      51           verbose: bool = False) -> np.ndarray:
#      52     """ Embed a list of n documents/words into an n-dimensional
#      53     matrix of embeddings
#      54
#    (...)
#      61         that each have an embeddings size of `m`
#      62     """
# ---> 63     embeddings = self.embedding_model.encode(documents, show_progress_bar=verbose)
#      64     return embeddings
#
# File ~/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/sentence_transformers/SentenceTransformer.py:165, in SentenceTransformer.encode(self, sentences, batch_size, show_progress_bar, output_value, convert_to_numpy, convert_to_tensor, device, normalize_embeddings)
#     162 features = batch_to_device(features, device)
#     164 with torch.no_grad():
# --> 165     out_features = self.forward(features)
#     167     if output_value == 'token_embeddings':
#     168         embeddings = []
#
# File ~/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/torch/nn/modules/container.py:204, in Sequential.forward(self, input)
#     202 def forward(self, input):
#     203     for module in self:
# --> 204         input = module(input)
#     205     return input
#
# File ~/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/torch/nn/modules/module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/sentence_transformers/models/Transformer.py:66, in Transformer.forward(self, features)
#      63 if 'token_type_ids' in features:
#      64     trans_features['token_type_ids'] = features['token_type_ids']
# ---> 66 output_states = self.auto_model(**trans_features, return_dict=False)
#      67 output_tokens = output_states[0]
#      69 features.update({'token_embeddings': output_tokens, 'attention_mask': features['attention_mask']})
#
# File ~/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/torch/nn/modules/module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/transformers/models/bert/modeling_bert.py:1019, in BertModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#    1010 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
#    1012 embedding_output = self.embeddings(
#    1013     input_ids=input_ids,
#    1014     position_ids=position_ids,
#    (...)
#    1017     past_key_values_length=past_key_values_length,
#    1018 )
# -> 1019 encoder_outputs = self.encoder(
#    1020     embedding_output,
#    1021     attention_mask=extended_attention_mask,
#    1022     head_mask=head_mask,
#    1023     encoder_hidden_states=encoder_hidden_states,
#    1024     encoder_attention_mask=encoder_extended_attention_mask,
#    1025     past_key_values=past_key_values,
#    1026     use_cache=use_cache,
#    1027     output_attentions=output_attentions,
#    1028     output_hidden_states=output_hidden_states,
#    1029     return_dict=return_dict,
#    1030 )
#    1031 sequence_output = encoder_outputs[0]
#    1032 pooled_output = self.pooler(sequence_output) if self.pooler is not None else None
#
# File ~/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/torch/nn/modules/module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/transformers/models/bert/modeling_bert.py:609, in BertEncoder.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     600     layer_outputs = torch.utils.checkpoint.checkpoint(
#     601         create_custom_forward(layer_module),
#     602         hidden_states,
#    (...)
#     606         encoder_attention_mask,
#     607     )
#     608 else:
# --> 609     layer_outputs = layer_module(
#     610         hidden_states,
#     611         attention_mask,
#     612         layer_head_mask,
#     613         encoder_hidden_states,
#     614         encoder_attention_mask,
#     615         past_key_value,
#     616         output_attentions,
#     617     )
#     619 hidden_states = layer_outputs[0]
#     620 if use_cache:
#
# File ~/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/torch/nn/modules/module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/transformers/models/bert/modeling_bert.py:537, in BertLayer.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     534     cross_attn_present_key_value = cross_attention_outputs[-1]
#     535     present_key_value = present_key_value + cross_attn_present_key_value
# --> 537 layer_output = apply_chunking_to_forward(
#     538     self.feed_forward_chunk, self.chunk_size_feed_forward, self.seq_len_dim, attention_output
#     539 )
#     540 outputs = (layer_output,) + outputs
#     542 # if decoder, return the attn key/values as the last output
#
# File ~/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/transformers/pytorch_utils.py:249, in apply_chunking_to_forward(forward_fn, chunk_size, chunk_dim, *input_tensors)
#     246     # concatenate output at same dimension
#     247     return torch.cat(output_chunks, dim=chunk_dim)
# --> 249 return forward_fn(*input_tensors)
#
# File ~/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/transformers/models/bert/modeling_bert.py:550, in BertLayer.feed_forward_chunk(self, attention_output)
#     548 def feed_forward_chunk(self, attention_output):
#     549     intermediate_output = self.intermediate(attention_output)
# --> 550     layer_output = self.output(intermediate_output, attention_output)
#     551     return layer_output
#
# File ~/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/torch/nn/modules/module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/transformers/models/bert/modeling_bert.py:462, in BertOutput.forward(self, hidden_states, input_tensor)
#     461 def forward(self, hidden_states: torch.Tensor, input_tensor: torch.Tensor) -> torch.Tensor:
# --> 462     hidden_states = self.dense(hidden_states)
#     463     hidden_states = self.dropout(hidden_states)
#     464     hidden_states = self.LayerNorm(hidden_states + input_tensor)
#
# File ~/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/torch/nn/modules/module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/torch/nn/modules/linear.py:114, in Linear.forward(self, input)
#     113 def forward(self, input: Tensor) -> Tensor:
# --> 114     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
#u_mass_scores = compute_coherence_scores(documents=docs, bert_models=modellist, coherence_method="u_mass", path=savepath)
#u_mass_scores.to_csv(f"../../exports/tables/coherence_scores_u_mass_size_comparison_" + modelname+ ".csv")
#u_mass_scores
# Out:
# /Users/dom/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning:
#
# Mean of empty slice.
#
# /Users/dom/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/numpy/core/_methods.py:190: RuntimeWarning:
#
# invalid value encountered in double_scalars
# BERT Model BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_96T.model: nan
# /Users/dom/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning:
#
# Mean of empty slice.
#
# /Users/dom/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/numpy/core/_methods.py:190: RuntimeWarning:
#
# invalid value encountered in double_scalars
# BERT Model BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_94T.model: nan
# /Users/dom/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning:
#
# Mean of empty slice.
#
# /Users/dom/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/numpy/core/_methods.py:190: RuntimeWarning:
#
# invalid value encountered in double_scalars
# BERT Model BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_92T.model: nan
# /Users/dom/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning:
#
# Mean of empty slice.
#
# /Users/dom/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/numpy/core/_methods.py:190: RuntimeWarning:
#
# invalid value encountered in double_scalars
# BERT Model BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_90T.model: nan
# /Users/dom/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning:
#
# Mean of empty slice.
#
# /Users/dom/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/numpy/core/_methods.py:190: RuntimeWarning:
#
# invalid value encountered in double_scalars
# BERT Model BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_88T.model: nan
# /Users/dom/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning:
#
# Mean of empty slice.
#
# /Users/dom/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/numpy/core/_methods.py:190: RuntimeWarning:
#
# invalid value encountered in double_scalars
# BERT Model BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_86T.model: nan
# /Users/dom/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning:
#
# Mean of empty slice.
#
# /Users/dom/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/numpy/core/_methods.py:190: RuntimeWarning:
#
# invalid value encountered in double_scalars
# BERT Model BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_84T.model: nan
# /Users/dom/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning:
#
# Mean of empty slice.
#
# /Users/dom/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/numpy/core/_methods.py:190: RuntimeWarning:
#
# invalid value encountered in double_scalars
# BERT Model BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_82T.model: nan
# /Users/dom/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning:
#
# Mean of empty slice.
#
# /Users/dom/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/numpy/core/_methods.py:190: RuntimeWarning:
#
# invalid value encountered in double_scalars
# BERT Model BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_80T.model: nan
# /Users/dom/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning:
#
# Mean of empty slice.
#
# /Users/dom/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/numpy/core/_methods.py:190: RuntimeWarning:
#
# invalid value encountered in double_scalars
# BERT Model BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_78T.model: nan
# /Users/dom/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning:
#
# Mean of empty slice.
#
# /Users/dom/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/numpy/core/_methods.py:190: RuntimeWarning:
#
# invalid value encountered in double_scalars
# BERT Model BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_76T.model: nan
# /Users/dom/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning:
#
# Mean of empty slice.
#
# /Users/dom/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/numpy/core/_methods.py:190: RuntimeWarning:
#
# invalid value encountered in double_scalars
# BERT Model BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_74T.model: nan
# /Users/dom/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning:
#
# Mean of empty slice.
#
# /Users/dom/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/numpy/core/_methods.py:190: RuntimeWarning:
#
# invalid value encountered in double_scalars
# BERT Model BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_72T.model: nan
# /Users/dom/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning:
#
# Mean of empty slice.
#
# /Users/dom/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/numpy/core/_methods.py:190: RuntimeWarning:
#
# invalid value encountered in double_scalars
# BERT Model BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_70T.model: nan
# /Users/dom/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning:
#
# Mean of empty slice.
#
# /Users/dom/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/numpy/core/_methods.py:190: RuntimeWarning:
#
# invalid value encountered in double_scalars
# BERT Model BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_68T.model: nan
# /Users/dom/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning:
#
# Mean of empty slice.
#
# /Users/dom/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/numpy/core/_methods.py:190: RuntimeWarning:
#
# invalid value encountered in double_scalars
# BERT Model BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_66T.model: nan
# /Users/dom/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning:
#
# Mean of empty slice.
#
# /Users/dom/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/numpy/core/_methods.py:190: RuntimeWarning:
#
# invalid value encountered in double_scalars
# BERT Model BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_64T.model: nan
# /Users/dom/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning:
#
# Mean of empty slice.
#
# /Users/dom/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/numpy/core/_methods.py:190: RuntimeWarning:
#
# invalid value encountered in double_scalars
# BERT Model BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_62T.model: nan
# /Users/dom/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning:
#
# Mean of empty slice.
#
# /Users/dom/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/numpy/core/_methods.py:190: RuntimeWarning:
#
# invalid value encountered in double_scalars
# BERT Model BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_60T.model: nan
# /Users/dom/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning:
#
# Mean of empty slice.
#
# /Users/dom/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/numpy/core/_methods.py:190: RuntimeWarning:
#
# invalid value encountered in double_scalars
# BERT Model BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_58T.model: nan
# /Users/dom/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning:
#
# Mean of empty slice.
#
# /Users/dom/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/numpy/core/_methods.py:190: RuntimeWarning:
#
# invalid value encountered in double_scalars
# BERT Model BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_56T.model: nan
# /Users/dom/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning:
#
# Mean of empty slice.
#
# /Users/dom/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/numpy/core/_methods.py:190: RuntimeWarning:
#
# invalid value encountered in double_scalars
# BERT Model BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_54T.model: nan
# /Users/dom/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning:
#
# Mean of empty slice.
#
# /Users/dom/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/numpy/core/_methods.py:190: RuntimeWarning:
#
# invalid value encountered in double_scalars
# BERT Model BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_52T.model: nan
# /Users/dom/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning:
#
# Mean of empty slice.
#
# /Users/dom/opt/anaconda3/envs/nlp/lib/python3.8/site-packages/numpy/core/_methods.py:190: RuntimeWarning:
#
# invalid value encountered in double_scalars
# BERT Model BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_50T.model: nan
# BERT Model BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_48T.model: -0.5870833790090406
# BERT Model BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_46T.model: -0.5845776586167967
# BERT Model BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_44T.model: -0.5694058957252598
# BERT Model BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_42T.model: -0.5667442669385025
# BERT Model BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_40T.model: -0.5489231839161646
# BERT Model BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_38T.model: -0.5226131857029658
# BERT Model BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_36T.model: -0.5119868884727521
# BERT Model BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_34T.model: -0.5230664102928514
# BERT Model BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_32T.model: -0.5057669522947242
# BERT Model BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_30T.model: -0.4767235047666302
# BERT Model BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_28T.model: -0.4707837992991948
# BERT Model BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_26T.model: -0.4375869278094124
# BERT Model BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_24T.model: -0.3903146027337991
# BERT Model BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_22T.model: -0.37098885066361414
# BERT Model BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_20T.model: -0.32946552451529204
# BERT Model BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_18T.model: -0.2966531088775704
# BERT Model BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_16T.model: -0.26555115868617496
# BERT Model BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_14T.model: -0.26750894013807286
# BERT Model BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_12T.model: -0.23957016297045497
# BERT Model BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_10T.model: -0.22053067922613134
# BERT Model BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_8T.model: -0.1952961854953967
# BERT Model BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_6T.model: -0.1560786443286215
# BERT Model BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_4T.model: -0.10859498365813736
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_96T.model         NaN
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_94T.model         NaN
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_92T.model         NaN
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_90T.model         NaN
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_88T.model         NaN
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_86T.model         NaN
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_84T.model         NaN
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_82T.model         NaN
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_80T.model         NaN
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_78T.model         NaN
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_76T.model         NaN
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_74T.model         NaN
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_72T.model         NaN
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_70T.model         NaN
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_68T.model         NaN
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_66T.model         NaN
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_64T.model         NaN
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_62T.model         NaN
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_60T.model         NaN
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_58T.model         NaN
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_56T.model         NaN
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_54T.model         NaN
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_52T.model         NaN
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_50T.model         NaN
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_48T.model   -0.587083
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_46T.model   -0.584578
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_44T.model   -0.569406
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_42T.model   -0.566744
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_40T.model   -0.548923
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_38T.model   -0.522613
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_36T.model   -0.511987
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_34T.model   -0.523066
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_32T.model   -0.505767
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_30T.model   -0.476724
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_28T.model   -0.470784
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_26T.model   -0.437587
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_24T.model   -0.390315
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_22T.model   -0.370989
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_20T.model   -0.329466
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_18T.model   -0.296653
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_16T.model   -0.265551
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_14T.model   -0.267509
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_12T.model   -0.239570
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_10T.model   -0.220531
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_8T.model    -0.195296
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_6T.model    -0.156079
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_4T.model    -0.108595
# dtype: float64

# %%
c_v_scores = compute_coherence_scores(documents=docs, bert_models=modellist, coherence_method="c_v", path=savepath)
c_v_scores.to_csv(f"../../exports/tables/coherence_scores_c_v_size_comparison_" + modelname+ ".csv")
c_v_scores
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# BERT Model BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_96T.model: 0.6890932204654187
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# BERT Model BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_94T.model: 0.6860889775651435
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# BERT Model BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_92T.model: 0.6863260163762307
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# BERT Model BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_90T.model: 0.6867190817777852
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# BERT Model BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_88T.model: 0.6880503505777649
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# BERT Model BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_86T.model: 0.6882710150867839
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# BERT Model BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_84T.model: 0.6895443618274134
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# BERT Model BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_82T.model: 0.6862963282654411
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# BERT Model BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_80T.model: 0.688559817973619
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# BERT Model BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_78T.model: 0.6933101270727071
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# BERT Model BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_76T.model: 0.6967636358969626
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# BERT Model BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_74T.model: 0.7010893874055555
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# BERT Model BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_72T.model: 0.707881975106149
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# ...
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# BERT Model BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_10T.model: 0.6816697051252357
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# BERT Model BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_8T.model: 0.6779245307203973
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# BERT Model BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_6T.model: 0.6755956793890768
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# BERT Model BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_4T.model: 0.6370191372681855
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_96T.model    0.689093
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_94T.model    0.686089
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_92T.model    0.686326
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_90T.model    0.686719
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_88T.model    0.688050
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_86T.model    0.688271
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_84T.model    0.689544
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_82T.model    0.686296
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_80T.model    0.688560
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_78T.model    0.693310
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_76T.model    0.696764
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_74T.model    0.701089
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_72T.model    0.707882
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_70T.model    0.710437
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_68T.model    0.712518
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_66T.model    0.720875
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_64T.model    0.722123
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_62T.model    0.728075
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_60T.model    0.726615
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_58T.model    0.725550
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_56T.model    0.729137
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_54T.model    0.724259
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_52T.model    0.720421
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_50T.model    0.718165
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_48T.model    0.717545
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_46T.model    0.714856
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_44T.model    0.704726
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_42T.model    0.708524
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_40T.model    0.703855
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_38T.model    0.699818
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_36T.model    0.700287
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_34T.model    0.704182
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_32T.model    0.694543
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_30T.model    0.694891
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_28T.model    0.698644
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_26T.model    0.692986
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_24T.model    0.693011
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_22T.model    0.687532
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_20T.model    0.684751
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_18T.model    0.698409
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_16T.model    0.708060
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_14T.model    0.700771
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_12T.model    0.676268
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_10T.model    0.681670
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_8T.model     0.677925
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_6T.model     0.675596
# BERTTopic_paraphrase-multilingual-MiniLM-L12-v2_4T.model     0.637019
# dtype: float64

# %%
## Import dataframe
filelocation = "../../exports/tables/cv_score_comparison.csv"
df_scores = pd.read_csv(filelocation)

# %%
df_scores
# Out:
#                                             Modelname  cv_score  topics
# 0   BERTTopic_paraphrase-multilingual-MiniLM-L12-v...  0.689093      96
# 1   BERTTopic_paraphrase-multilingual-MiniLM-L12-v...  0.686089      94
# 2   BERTTopic_paraphrase-multilingual-MiniLM-L12-v...  0.686326      92
# 3   BERTTopic_paraphrase-multilingual-MiniLM-L12-v...  0.686719      90
# 4   BERTTopic_paraphrase-multilingual-MiniLM-L12-v...  0.688050      88
# 5   BERTTopic_paraphrase-multilingual-MiniLM-L12-v...  0.688271      86
# 6   BERTTopic_paraphrase-multilingual-MiniLM-L12-v...  0.689544      84
# 7   BERTTopic_paraphrase-multilingual-MiniLM-L12-v...  0.686296      82
# 8   BERTTopic_paraphrase-multilingual-MiniLM-L12-v...  0.688560      80
# 9   BERTTopic_paraphrase-multilingual-MiniLM-L12-v...  0.693310      78
# 10  BERTTopic_paraphrase-multilingual-MiniLM-L12-v...  0.696764      76
# 11  BERTTopic_paraphrase-multilingual-MiniLM-L12-v...  0.701089      74
# 12  BERTTopic_paraphrase-multilingual-MiniLM-L12-v...  0.707882      72
# 13  BERTTopic_paraphrase-multilingual-MiniLM-L12-v...  0.710437      70
# 14  BERTTopic_paraphrase-multilingual-MiniLM-L12-v...  0.712518      68
# 15  BERTTopic_paraphrase-multilingual-MiniLM-L12-v...  0.720875      66
# 16  BERTTopic_paraphrase-multilingual-MiniLM-L12-v...  0.722123      64
# 17  BERTTopic_paraphrase-multilingual-MiniLM-L12-v...  0.728075      62
# 18  BERTTopic_paraphrase-multilingual-MiniLM-L12-v...  0.726615      60
# 19  BERTTopic_paraphrase-multilingual-MiniLM-L12-v...  0.725550      58
# 20  BERTTopic_paraphrase-multilingual-MiniLM-L12-v...  0.729137      56
# 21  BERTTopic_paraphrase-multilingual-MiniLM-L12-v...  0.724259      54
# 22  BERTTopic_paraphrase-multilingual-MiniLM-L12-v...  0.720421      52
# 23  BERTTopic_paraphrase-multilingual-MiniLM-L12-v...  0.718165      50
# 24  BERTTopic_paraphrase-multilingual-MiniLM-L12-v...  0.717545      48
# 25  BERTTopic_paraphrase-multilingual-MiniLM-L12-v...  0.714856      46
# 26  BERTTopic_paraphrase-multilingual-MiniLM-L12-v...  0.704726      44
# 27  BERTTopic_paraphrase-multilingual-MiniLM-L12-v...  0.708524      42
# 28  BERTTopic_paraphrase-multilingual-MiniLM-L12-v...  0.703855      40
# 29  BERTTopic_paraphrase-multilingual-MiniLM-L12-v...  0.699818      38
# 30  BERTTopic_paraphrase-multilingual-MiniLM-L12-v...  0.700287      36
# 31  BERTTopic_paraphrase-multilingual-MiniLM-L12-v...  0.704182      34
# 32  BERTTopic_paraphrase-multilingual-MiniLM-L12-v...  0.694543      32
# 33  BERTTopic_paraphrase-multilingual-MiniLM-L12-v...  0.694891      30
# 34  BERTTopic_paraphrase-multilingual-MiniLM-L12-v...  0.698644      28
# 35  BERTTopic_paraphrase-multilingual-MiniLM-L12-v...  0.692986      26
# 36  BERTTopic_paraphrase-multilingual-MiniLM-L12-v...  0.693011      24
# 37  BERTTopic_paraphrase-multilingual-MiniLM-L12-v...  0.687532      22
# 38  BERTTopic_paraphrase-multilingual-MiniLM-L12-v...  0.684751      20
# 39  BERTTopic_paraphrase-multilingual-MiniLM-L12-v...  0.698409      18
# 40  BERTTopic_paraphrase-multilingual-MiniLM-L12-v...  0.708060      16
# 41  BERTTopic_paraphrase-multilingual-MiniLM-L12-v...  0.700771      14
# 42  BERTTopic_paraphrase-multilingual-MiniLM-L12-v...  0.676268      12
# 43  BERTTopic_paraphrase-multilingual-MiniLM-L12-v...  0.681670      10
# 44  BERTTopic_paraphrase-multilingual-MiniLM-L12-v...  0.677925       8
# 45  BERTTopic_paraphrase-multilingual-MiniLM-L12-v...  0.675596       6
# 46  BERTTopic_paraphrase-multilingual-MiniLM-L12-v...  0.637019       4

# %%
#c_v_scores_df = c_v_scores.to_frame(name="c_v")
#u_mass_df = u_mass_scores.to_frame(name="u_mass")
#scores_df = c_v_scores_df.join(u_mass_df)
#scores_df['topicnumber']= list(range(96,2,-2))

# %%
import plotly.express as px
import pandas as pd

# create the line chart
fig = px.line(
    df_scores,
    x='topics',
    y='cv_score',
    color_discrete_sequence=color_discrete_sequence,
    #template=template
    )

fig.update_layout(
    title="Entwicklung C_v Score mit abnehmender Themenanzahl",
    width=900, 
    height=450,
    legend_title="")

fig.update_yaxes(range=(0.62, 0.8), title=dict(text='C_v Score', font=dict(size=12)))
fig.update_xaxes(title=dict(text='Themenanzahl', font=dict(size=12)))
# show the chart
fig.show()

pio.write_image(fig,"../../exports/images/fig-topic-size-comparison.svg") #save fig as svg

# %% [markdown]
# ## Explore Topic Keywords

# %%
# Load the orginal Model
topic_model = BERTopic.load("../../models/BERTTopic_all-MiniLM-L6-v2.model")

# %%
#Select Topic model
model = topic_model
modelname = 'BERTTopic_all-MiniLM-L6-v2'

df_topic_keywords = get_topic_keywords_df(model)
df_topic_freq = model.get_topic_freq()
df_topics = pd.merge(df_topic_keywords, df_topic_freq, left_on='topic_id', right_on='Topic', how='left')
# reorder columns to place the new column as the second column
df_topics = df_topics.reindex(columns=['Topic','Count', 'keyword 1', 'keyword 2','keyword 3','keyword 4','keyword 5','keyword 6','keyword 7','keyword 8','keyword 9','keyword 10'])
df_topics.to_csv(f"../../exports/tables/topic_keywords_"+ modelname+".csv")
df_topics
# Out:
#      Topic  Count          keyword 1   keyword 2  keyword 3  keyword 4  \
# 0       -1    222              danke       alles        gut       nein
# 1        0   2015            bahnhof   bahnhöfen       bahn         am
# 2        1   1678                ich         und        die        der
# 3        2   1443             ticket     tickets        app      lösen
# 4        3   1240      maskenpflicht       maske     masken     tragen
# ..     ...    ...                ...         ...        ...        ...
# 134    133    110            locarno  bellinzona  wartezeit  baustelle
# 135    134     66            minibar         bar       mini     kaffee
# 136    135     87            perfekt       alles         io      danke
# 137    136     79           anpassen      preise      preis   leistung
# 138    137    116  sicherheitskräfte  sicherheit     gefühl      abend
#
#               keyword 5     keyword 6        keyword 7      keyword 8  \
# 0                weiter         platz             mehr             so
# 1                   den      bahnhöfe               an            und
# 2                  dass           den              mit            das
# 3                   ein           das              ich         kaufen
# 4                  ohne         keine              die          leute
# ..                  ...           ...              ...            ...
# 134          verbindung          nach              von        direkte
# 135            minibars      vermisse        einführen    speisewagen
# 136                 war       tellbus              bus  tschiertschen
# 137              bedarf  bedürfnissen  erstklasswagons  deutschenbahn
# 138  sicherheitskräften        abends             eher           mehr
#
#          keyword 9             keyword 10
# 0          bleiben                  weiss
# 1               in                     im
# 2            nicht                     in
# 3     ticketpreise                    für
# 4         getragen                   nase
# ..             ...                    ...
# 134          luino                  lange
# 135         wieder             minimieren
# 136  tellbusfahrer                brunnen
# 137       fahrplan                  wynau
# 138             am  sicherheitskontrollen
#
# [139 rows x 12 columns]
